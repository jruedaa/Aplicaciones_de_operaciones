# %%
import numpy as np
from os import listdir
from os.path import join
import cv2

# %%
def load_images(path,width=100):
    rawImgs= []
    labels=[]

    files_list=listdir(path)
    for item in tqdm(files_list):
        file=join(path,item)
        if file[-1] == 'g':
            img=cv2.imread(file)
            img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            img=cv2.resize(img,(width,width))
            rawImgs.append(img)
            l=path.split('/')[-1]
            if l=='benign':
                labels.append([1])
            else:
                labels.append([0])
    return rawImgs, labels,files_list
